# %%
import pandas as pd

df = pd.read_json('orders_simple.json', orient="records")
df.head()
# Out:
#    order_id  customer_id        order_date country       city category_main  \
# 0      1001         5506  2025-11-01 11:15  Israel   Tel Aviv       Fashion
# 1      1002         1434  2025-11-02 16:15     USA    Chicago        Sports
# 2      1003         6514   2025-11-03 9:05     USA   New York        Sports
# 3      1004         2291  2025-11-04 16:25  Israel  Jerusalem          Home
# 4      1005         8428  2025-11-05 18:25  France       Lyon       Fashion
#
#                                           items_html total_amount  \
# 0  <b>iPhone 14</b><br>Silicone Case<br>Screen Pr...     1023.13$
# 1                 <b>Nike Shoes</b><br>Running Socks      687.58$
# 2  <b>iPhone 14</b><br>Silicone Case<br>Screen Pr...      554.49$
# 3                 <b>Nike Shoes</b><br>Running Socks     1064.24$
# 4               <b>AirPods Pro</b><br>Charging Cable      549.02$
#
#   payment_status  shipping_days  coupon_used  customer_age  rating is_returned
# 0       Refunded              2                         20     3.5        True
# 1        Pending              1  BLACKFRIDAY            62     4.5       False
# 2        Pending             10     SUMMER15            69     3.5       False
# 3           Paid              4     SUMMER15            23     4.0       False
# 4       Refunded              5    WELCOME10            56     4.0       False

# %%
df['total_amount'] = df['total_amount'].str.replace('$', '')
df = df.astype({"total_amount": "float","shipping_days": "int64","customer_age": "int64"})
df["order_date"] = pd.to_datetime(df["order_date"])



# df['total_amount'] = df['total_amount'].replace('$', '')
# df = df.astype({"total_amount": "float","shipping_days": "int64","customer_age": "int64"})
# df["order_date"] = pd.to_datetime(df["order_date"])
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df['total_amount'] = df['total_amount'].str.replace('$', '')
#       2 df = df.astype({"total_amount": "float","shipping_days": "int64","customer_age": "int64"})
#       3 df["order_date"] = pd.to_datetime(df["order_date"])
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6321, in NDFrame.__getattr__(self, name)
#    6314 if (
#    6315     name not in self._internal_names_set
#    6316     and name not in self._metadata
#    6317     and name not in self._accessors
#    6318     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319 ):
#    6320     return self[name]
# -> 6321 return object.__getattribute__(self, name)
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\strings\accessor.py:194, in StringMethods.__init__(self, data)
#     191 def __init__(self, data) -> None:
#     192     from pandas.core.arrays.string_ import StringDtype
# --> 194     self._inferred_dtype = self._validate(data)
#     195     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     196     self._is_string = isinstance(data.dtype, StringDtype)
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\strings\accessor.py:248, in StringMethods._validate(data)
#     245 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     247 if inferred_dtype not in allowed_types:
# --> 248     raise AttributeError("Can only use .str accessor with string values!")
#     249 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
# df.replace({"items_html": {"<": "", "</b>": " ","<br>":" "}})
df['items_html'] =df['items_html'].str.replace('<b>', ' ')
df['items_html'] =df['items_html'].str.replace('</b>', ' ')
df.head()
# Out:
#    order_id  customer_id          order_date country       city category_main  \
# 0      1001         5506 2025-11-01 11:15:00  Israel   Tel Aviv       Fashion
# 1      1002         1434 2025-11-02 16:15:00     USA    Chicago        Sports
# 2      1003         6514 2025-11-03 09:05:00     USA   New York        Sports
# 3      1004         2291 2025-11-04 16:25:00  Israel  Jerusalem          Home
# 4      1005         8428 2025-11-05 18:25:00  France       Lyon       Fashion
#
#                                           items_html  total_amount  \
# 0  b>iPhone 14/b>br>Silicone Casebr>Screen Protector       1023.13
# 1                    b>Nike Shoes/b>br>Running Socks        687.58
# 2  b>iPhone 14/b>br>Silicone Casebr>Screen Protector        554.49
# 3                    b>Nike Shoes/b>br>Running Socks       1064.24
# 4                  b>AirPods Pro/b>br>Charging Cable        549.02
#
#   payment_status  shipping_days  coupon_used  customer_age  rating  \
# 0       Refunded              2    no_coupon            20     3.5
# 1        Pending              1  BLACKFRIDAY            62     4.5
# 2        Pending             10     SUMMER15            69     3.5
# 3           Paid              4     SUMMER15            23     4.0
# 4       Refunded              5    WELCOME10            56     4.0
#
#   is_returned  order_month  high_value_order  average_rating delivery_status
# 0        True           11              True        4.334146         on_time
# 1       False           11             False        4.237500         on_time
# 2       False           11             False        4.237500         delayed
# 3       False           11              True        4.334146         on_time
# 4       False           11             False        4.183077         on_time

# %%
#3
df['coupon_used'] = df['coupon_used'].replace('','no_coupon')

# %%
#4
df['order_month']=df['order_date'].dt.month
df.head()
# Out:
#    order_id  customer_id          order_date country       city category_main  \
# 0      1001         5506 2025-11-01 11:15:00  Israel   Tel Aviv       Fashion
# 1      1002         1434 2025-11-02 16:15:00     USA    Chicago        Sports
# 2      1003         6514 2025-11-03 09:05:00     USA   New York        Sports
# 3      1004         2291 2025-11-04 16:25:00  Israel  Jerusalem          Home
# 4      1005         8428 2025-11-05 18:25:00  France       Lyon       Fashion
#
#                                           items_html  total_amount  \
# 0  b>iPhone 14/b>br>Silicone Casebr>Screen Protector       1023.13
# 1                    b>Nike Shoes/b>br>Running Socks        687.58
# 2  b>iPhone 14/b>br>Silicone Casebr>Screen Protector        554.49
# 3                    b>Nike Shoes/b>br>Running Socks       1064.24
# 4                  b>AirPods Pro/b>br>Charging Cable        549.02
#
#   payment_status  shipping_days  coupon_used  customer_age  rating  \
# 0       Refunded              2                         20     3.5
# 1        Pending              1  BLACKFRIDAY            62     4.5
# 2        Pending             10     SUMMER15            69     3.5
# 3           Paid              4     SUMMER15            23     4.0
# 4       Refunded              5    WELCOME10            56     4.0
#
#   is_returned  order_month
# 0        True           11
# 1       False           11
# 2       False           11
# 3       False           11
# 4       False           11

# %%
#5

average_amount = df['total_amount'].mean()
df['high_value_order'] = df['total_amount'] > average_amount
df = df.sort_values(by='total_amount', ascending=False)
df.head()

# otal = int(df['total_amount'].mean())

# df['high_value_order'] = df['total_amount'].apply(lambda x: True if x > total else False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 #5
# ----> 3 average_amount = df['total_amount'].mean()
#       4 df['high_value_order'] = df['total_amount'] > average_amount
#       5 df = df.sort_values(by='total_amount', ascending=False)
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:6570, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6562 @doc(make_doc("mean", ndim=1))
#    6563 def mean(
#    6564     self,
#    (...)   6568     **kwargs,
#    6569 ):
# -> 6570     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12478 def mean(
#   12479     self,
#   12480     axis: Axis | None = 0,
#    (...)  12483     **kwargs,
#   12484 ) -> Series | float:
# > 12485     return self._stat_function(
#   12486         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12487     )
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12442, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12438 nv.validate_func(name, (), kwargs)
#   12440 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12442 return self._reduce(
#   12443     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12444 )
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:6478, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6473     # GH#47500 - change to TypeError to match other methods
#    6474     raise TypeError(
#    6475         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6476         "with non-numeric dtypes."
#    6477     )
# -> 6478 return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#     723     count = cast(np.ndarray, count)
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(x)
#    1698 elif not (is_float(x) or is_integer(x) or is_complex(x)):
#    1699     if isinstance(x, str):
#    1700         # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701         raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702     try:
#    1703         x = float(x)
#
# TypeError: Could not convert string '1023.13$687.58$554.49$1064.24$549.02$1268.21$235.74$1139.78$1030.52$1266.46$1321.11$998.13$671.20$1069.07$383.42$618.87$678.62$1300.36$305.10$126.07$326.28$941.21$671.32$440.59$30.23$1256.03$1175.67$418.54$998.55$288.39$90.47$1008.67$833.21$996.80$926.63$1173.17$928.66$949.45$589.98$1288.68$348.65$898.04$695.68$355.73$1056.71$1413.67$126.71$1107.35$1131.95$437.50$1194.58$1061.71$1114.44$92.14$674.69$1221.43$475.44$255.89$652.08$1057.11$362.66$1495.49$450.12$104.95$204.10$1421.91$590.79$1260.28$1471.64$211.21$1177.75$955.96$503.45$939.07$133.95$587.51$1169.22$74.21$1249.95$158.20$720.43$91.89$1330.99$1286.79$1185.52$1291.15$282.01$768.16$133.40$1194.82$654.48$890.04$177.81$1271.60$1308.05$484.67$920.44$91.99$758.64$703.14$1206.95$1125.06$241.01$247.66$80.47$917.38$1068.74$122.22$1452.35$775.02$1270.53$1088.74$1449.26$1229.91$427.37$594.60$1144.29$469.20$454.63$1313.16$90.40$79.55$551.54$1045.80$143.10$931.91$124.17$871.53$411.12$1350.55$204.01$612.29$1028.16$500.92$897.92$985.42$132.64$217.88$1419.44$1321.64$906.34$91.73$214.78$91.82$773.29$1200.21$1236.95$1312.41$830.75$492.64$449.25$186.11$1083.10$977.70$1406.50$1280.31$1191.38$729.24$989.18$567.13$1028.50$508.97$782.04$878.01$1159.23$199.98$1239.46$124.25$231.70$468.24$627.18$1452.48$101.02$1407.31$812.13$486.56$865.44$1087.46$1267.75$810.01$1379.12$858.38$964.20$1354.38$890.88$763.67$1180.73$1076.84$555.88$1298.98$421.66$1417.73$518.74$1108.94$1430.68$996.53$1191.31$181.27$1496.61$538.74$' to numeric

# %%
#6

df['average_rating']=df.groupby('country')['rating'].transform("mean")
df.head()
# Out:
#    order_id  customer_id        order_date country       city category_main  \
# 0      1001         5506  2025-11-01 11:15  Israel   Tel Aviv       Fashion
# 1      1002         1434  2025-11-02 16:15     USA    Chicago        Sports
# 2      1003         6514   2025-11-03 9:05     USA   New York        Sports
# 3      1004         2291  2025-11-04 16:25  Israel  Jerusalem          Home
# 4      1005         8428  2025-11-05 18:25  France       Lyon       Fashion
#
#                                           items_html total_amount  \
# 0  <b>iPhone 14</b><br>Silicone Case<br>Screen Pr...     1023.13$
# 1                 <b>Nike Shoes</b><br>Running Socks      687.58$
# 2  <b>iPhone 14</b><br>Silicone Case<br>Screen Pr...      554.49$
# 3                 <b>Nike Shoes</b><br>Running Socks     1064.24$
# 4               <b>AirPods Pro</b><br>Charging Cable      549.02$
#
#   payment_status  shipping_days  coupon_used  customer_age  rating  \
# 0       Refunded              2                         20     3.5
# 1        Pending              1  BLACKFRIDAY            62     4.5
# 2        Pending             10     SUMMER15            69     3.5
# 3           Paid              4     SUMMER15            23     4.0
# 4       Refunded              5    WELCOME10            56     4.0
#
#   is_returned  average_rating
# 0        True        4.334146
# 1       False        4.237500
# 2       False        4.237500
# 3       False        4.334146
# 4       False        4.183077

# %%
#7

filtered = df.query("total_amount > 1000 and rating >4.5")

# %%
#8
filtered['delivery_status'] = df['shipping_days'].apply(lambda x: 'delayed' if x > 7 else 'on_time')
filtered.head()

# %%
filtered.to_csv("clean_orders_[eliezer_yakovson].csv", index=False, encoding="utf-8-sig")
